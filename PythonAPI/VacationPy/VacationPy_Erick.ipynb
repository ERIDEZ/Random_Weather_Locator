# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\programdata\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from gmaps) (7.16.1)
# Requirement already satisfied: geojson>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\programdata\anaconda3\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\programdata\anaconda3\lib\site-packages (from gmaps) (4.3.3)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (49.2.0.post20200714)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.17.1)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.5)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.3)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.6.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.2)
# Requirement already satisfied: ipython-genutils in c:\programdata\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\programdata\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jupyter-core in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-client in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.6)
# Requirement already satisfied: tornado>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: terminado>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.3)
# Requirement already satisfied: Send2Trash in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: nbconvert in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (19.0.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\programdata\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.4)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import scipy.stats as st
import csv


# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
file_import = os.path.join("..","output_data","cities.csv")

# %%
with open(file_import, "r", encoding="utf-8-sig") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",")
    csv_header = next(csv_reader)
    cities_df = pd.DataFrame(csv_reader, columns = csv_header)

# %%
cities_df
# Out:
#                 City Cloudiness Country        Date Humidity Latitude  \
# 0    arraial do cabo         40      BR  1603380569       61   -22.97
# 1       ponta do sol         40      PT  1603380272       53    32.67
# 2            aklavik         90      CA  1603380327       78    68.22
# 3            te anau        100      NZ  1603380570       85   -45.42
# 4            kavieng         51      PG  1603380570       71    -2.57
# ..               ...        ...     ...         ...      ...      ...
# 578            bilma          0      NE  1603380808       11    18.69
# 579   port macquarie         90      AU  1603380702      100   -31.43
# 580         honggang          0      CN  1603380809       84    46.47
# 581       codrington        100      AU  1603380809       93   -38.27
# 582           evensk         96      RU  1603380810       88    61.95
#
#     Longitude Max temp Wind speed
# 0      -42.03       26        7.2
# 1       -17.1       22        1.5
# 2     -135.01       -9        3.1
# 3      167.72     6.28       0.84
# 4       150.8    28.38       4.12
# ..        ...      ...        ...
# 578     12.92    33.73       3.22
# 579    152.92    16.11          1
# 580    124.87    -0.41       3.97
# 581    141.97    11.14       2.43
# 582    159.23     1.63       2.01
#
# [583 rows x 9 columns]

# %%
cities_df.dtypes
# Out:
# City          object
# Cloudiness    object
# Country       object
# Date          object
# Humidity      object
# Latitude      object
# Longitude     object
# Max temp      object
# Wind speed    object
# dtype: object

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
import gmaps.datasets

# %%
gmaps.configure(api_key=g_key)

# %%
# Parametersm for figure display
coords = cities_df[["Latitude", "Longitude"]].astype(float)
humid = cities_df["Humidity"].astype(float)

# %%
figure_layout = {
    'width': '100%',
    'height': '500px',
    'border': '1px solid black',
    'margin': '0 auto 0 auto',
    'padding': '1px'
}

# %%
# Plot Heatmap

Max_Humid = humid.max()
fig = gmaps.figure(map_type="HYBRID", layout = figure_layout)

heat_layer = gmaps.heatmap_layer(coords, weights=humid, dissipating=False, max_intensity=Max_Humid, point_radius=0.9)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='500px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# 80 °F = 27 °C
# 70 °F = 21 °C
# 10 mph = 16kph
# data extracted in metric

# %%
# Data cleaning - zero cloudiness
cities1_df = cities_df[cities_df["Cloudiness"].astype(float)==0]
cities1_df
# Out:
#                 City Cloudiness Country        Date Humidity Latitude  \
# 5       khudumelapye          0      BW  1603380570       16   -23.88
# 6          carnarvon          0      AU  1603380570       72   -24.87
# 15            rawson          0      AR  1603380363       29    -43.3
# 19            linxia          0      CN  1603380550       52     35.6
# 26      saint-pierre          0      RE  1603380285       73   -21.34
# ..               ...        ...     ...         ...      ...      ...
# 565  sfantu gheorghe          0      RO  1603380764       57    45.87
# 567        dalbandin          0      PK  1603380805       26    28.89
# 570       walvis bay          0      NA  1603380806       64   -22.96
# 578            bilma          0      NE  1603380808       11    18.69
# 580         honggang          0      CN  1603380809       84    46.47
#
#     Longitude Max temp Wind speed
# 5       24.75    32.92       5.03
# 6      113.63       20        8.7
# 15      -65.1    20.97       5.29
# 19     103.21     8.79       0.54
# 26      55.48       24        8.7
# ..        ...      ...        ...
# 565     25.78    12.78       0.83
# 567     64.41    16.53       1.99
# 570     14.51       20        4.1
# 578     12.92    33.73       3.22
# 580    124.87    -0.41       3.97
#
# [105 rows x 9 columns]

# %%
# Data cleaning - max 10mph (16kph) wind speed
cities1_df=cities1_df[cities1_df["Wind speed"].astype(float)<=16]
cities1_df
# Out:
#                 City Cloudiness Country        Date Humidity Latitude  \
# 5       khudumelapye          0      BW  1603380570       16   -23.88
# 6          carnarvon          0      AU  1603380570       72   -24.87
# 15            rawson          0      AR  1603380363       29    -43.3
# 19            linxia          0      CN  1603380550       52     35.6
# 26      saint-pierre          0      RE  1603380285       73   -21.34
# ..               ...        ...     ...         ...      ...      ...
# 565  sfantu gheorghe          0      RO  1603380764       57    45.87
# 567        dalbandin          0      PK  1603380805       26    28.89
# 570       walvis bay          0      NA  1603380806       64   -22.96
# 578            bilma          0      NE  1603380808       11    18.69
# 580         honggang          0      CN  1603380809       84    46.47
#
#     Longitude Max temp Wind speed
# 5       24.75    32.92       5.03
# 6      113.63       20        8.7
# 15      -65.1    20.97       5.29
# 19     103.21     8.79       0.54
# 26      55.48       24        8.7
# ..        ...      ...        ...
# 565     25.78    12.78       0.83
# 567     64.41    16.53       1.99
# 570     14.51       20        4.1
# 578     12.92    33.73       3.22
# 580    124.87    -0.41       3.97
#
# [105 rows x 9 columns]

# %%
# # Data cleaning - temp between 80°F and 70°F (27°C and 21°C)
cities1_df=cities1_df[(cities1_df["Max temp"].astype(float)<=27) & (cities1_df["Max temp"].astype(float)>21)]
cities1_df
# Out:
#                  City Cloudiness Country        Date Humidity Latitude  \
# 26       saint-pierre          0      RE  1603380285       73   -21.34
# 27     cap malheureux          0      MU  1603380577       71   -19.98
# 63     port elizabeth          0      ZA  1603380383       78   -33.92
# 68             castro          0      BR  1603380586       50   -24.79
# 78        east london          0      ZA  1603380320       73   -33.02
# 80          cape town          0      ZA  1603380590       72   -33.93
# 90       port hedland          0      AU  1603380593       83   -20.32
# 112       port alfred          0      ZA  1603380597       71   -33.59
# 124          hermanus          0      ZA  1603380603       65   -34.42
# 144              faya          0      SA  1603380617       13    18.39
# 181            zaltan          0      LY  1603380637       49    32.95
# 184             mansa          0      IN  1603380639       20    29.98
# 199    saint-philippe          0      RE  1603380646       73   -21.36
# 225               hun          0      LY  1603380665       30    29.13
# 242              bhag          0      PK  1603380674       14    29.04
# 249           ajaccio          0      FR  1603380677       53       42
# 262              jalu          0      LY  1603380683       35    29.03
# 267         abu kamal          0      SY  1603380685       24    34.45
# 290  san buenaventura          0      MX  1603380697       62    27.08
# 309        nouadhibou          0      MR  1603380709       61    20.93
# 328            talara          0      PE  1603380721       73    -4.58
# 363               sur          0      OM  1603380738       61    22.57
# 456       grand gaube          0      MU  1603380775       71   -20.01
# 499          yasothon          0      TH  1603380788       78    15.75
# 515         wattegama          0      LK  1603380792       94      6.8
# 518      saint-joseph          0      RE  1603380792       73   -21.37
# 543            karhal          0      IN  1603380799       29       27
# 556        zvishavane          0      ZW  1603380803       39   -20.33
#
#     Longitude Max temp Wind speed
# 26      55.48       24        8.7
# 27      57.61    23.33       1.79
# 63      25.57       22        6.2
# 68     -50.01    23.84        4.3
# 78      27.91       23        7.7
# 80      18.42    21.11        9.3
# 90     118.57       23        4.6
# 112     26.89    23.02       8.67
# 124     19.23    22.78       3.13
# 144     42.45       24        4.6
# 181     11.87    25.08        6.7
# 184     75.38    22.83       2.09
# 199     55.77       24        8.7
# 225     15.95    22.84       1.55
# 242     67.82    23.95       0.52
# 249      8.92       23       1.01
# 262     21.55    22.09       4.38
# 267     40.92    25.49       4.08
# 290   -101.53     25.3       0.48
# 309    -17.03       27        7.2
# 328    -81.27       24        8.2
# 363     59.53    25.73        5.2
# 456     57.66    23.33       1.79
# 499    104.13       24        1.5
# 515     81.48       27        3.6
# 518     55.62       24        8.7
# 543     78.94    25.73       0.89
# 556     30.07    25.61       4.06

# %%
# Re-Index
cities1_df.index = range(len(cities1_df.index))
cities1_df
# Out:
#                 City Cloudiness Country        Date Humidity Latitude  \
# 0       saint-pierre          0      RE  1603380285       73   -21.34
# 1     cap malheureux          0      MU  1603380577       71   -19.98
# 2     port elizabeth          0      ZA  1603380383       78   -33.92
# 3             castro          0      BR  1603380586       50   -24.79
# 4        east london          0      ZA  1603380320       73   -33.02
# 5          cape town          0      ZA  1603380590       72   -33.93
# 6       port hedland          0      AU  1603380593       83   -20.32
# 7        port alfred          0      ZA  1603380597       71   -33.59
# 8           hermanus          0      ZA  1603380603       65   -34.42
# 9               faya          0      SA  1603380617       13    18.39
# 10            zaltan          0      LY  1603380637       49    32.95
# 11             mansa          0      IN  1603380639       20    29.98
# 12    saint-philippe          0      RE  1603380646       73   -21.36
# 13               hun          0      LY  1603380665       30    29.13
# 14              bhag          0      PK  1603380674       14    29.04
# 15           ajaccio          0      FR  1603380677       53       42
# 16              jalu          0      LY  1603380683       35    29.03
# 17         abu kamal          0      SY  1603380685       24    34.45
# 18  san buenaventura          0      MX  1603380697       62    27.08
# 19        nouadhibou          0      MR  1603380709       61    20.93
# 20            talara          0      PE  1603380721       73    -4.58
# 21               sur          0      OM  1603380738       61    22.57
# 22       grand gaube          0      MU  1603380775       71   -20.01
# 23          yasothon          0      TH  1603380788       78    15.75
# 24         wattegama          0      LK  1603380792       94      6.8
# 25      saint-joseph          0      RE  1603380792       73   -21.37
# 26            karhal          0      IN  1603380799       29       27
# 27        zvishavane          0      ZW  1603380803       39   -20.33
#
#    Longitude Max temp Wind speed
# 0      55.48       24        8.7
# 1      57.61    23.33       1.79
# 2      25.57       22        6.2
# 3     -50.01    23.84        4.3
# 4      27.91       23        7.7
# 5      18.42    21.11        9.3
# 6     118.57       23        4.6
# 7      26.89    23.02       8.67
# 8      19.23    22.78       3.13
# 9      42.45       24        4.6
# 10     11.87    25.08        6.7
# 11     75.38    22.83       2.09
# 12     55.77       24        8.7
# 13     15.95    22.84       1.55
# 14     67.82    23.95       0.52
# 15      8.92       23       1.01
# 16     21.55    22.09       4.38
# 17     40.92    25.49       4.08
# 18   -101.53     25.3       0.48
# 19    -17.03       27        7.2
# 20    -81.27       24        8.2
# 21     59.53    25.73        5.2
# 22     57.66    23.33       1.79
# 23    104.13       24        1.5
# 24     81.48       27        3.6
# 25     55.62       24        8.7
# 26     78.94    25.73       0.89
# 27     30.07    25.61       4.06

# %%
cities1_df[["Latitude", "Longitude"]]=cities1_df[["Latitude", "Longitude"]].astype(float)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
cities1_df.dtypes
# Out:
# City           object
# Cloudiness     object
# Country        object
# Date           object
# Humidity       object
# Latitude      float64
# Longitude     float64
# Max temp       object
# Wind speed     object
# dtype: object

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
cities1_df["Hotel Name"]=""
cities1_df["Hotel Address"]=""
cities1_df["Hotel Lat"]=""
cities1_df["Hotel Lon"]=""
# Out:
# <ipython-input-20-af377d066b2d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities1_df["Hotel Name"]=""
# <ipython-input-20-af377d066b2d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities1_df["Hotel Address"]=""
# <ipython-input-20-af377d066b2d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities1_df["Hotel Lat"]=""
# <ipython-input-20-af377d066b2d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities1_df["Hotel Lon"]=""

# %%
cities1_df
# Out:
#                 City Cloudiness Country        Date Humidity  Latitude  \
# 0       saint-pierre          0      RE  1603380285       73    -21.34
# 1     cap malheureux          0      MU  1603380577       71    -19.98
# 2     port elizabeth          0      ZA  1603380383       78    -33.92
# 3             castro          0      BR  1603380586       50    -24.79
# 4        east london          0      ZA  1603380320       73    -33.02
# 5          cape town          0      ZA  1603380590       72    -33.93
# 6       port hedland          0      AU  1603380593       83    -20.32
# 7        port alfred          0      ZA  1603380597       71    -33.59
# 8           hermanus          0      ZA  1603380603       65    -34.42
# 9               faya          0      SA  1603380617       13     18.39
# 10            zaltan          0      LY  1603380637       49     32.95
# 11             mansa          0      IN  1603380639       20     29.98
# 12    saint-philippe          0      RE  1603380646       73    -21.36
# 13               hun          0      LY  1603380665       30     29.13
# 14              bhag          0      PK  1603380674       14     29.04
# 15           ajaccio          0      FR  1603380677       53     42.00
# 16              jalu          0      LY  1603380683       35     29.03
# 17         abu kamal          0      SY  1603380685       24     34.45
# 18  san buenaventura          0      MX  1603380697       62     27.08
# 19        nouadhibou          0      MR  1603380709       61     20.93
# 20            talara          0      PE  1603380721       73     -4.58
# 21               sur          0      OM  1603380738       61     22.57
# 22       grand gaube          0      MU  1603380775       71    -20.01
# 23          yasothon          0      TH  1603380788       78     15.75
# 24         wattegama          0      LK  1603380792       94      6.80
# 25      saint-joseph          0      RE  1603380792       73    -21.37
# 26            karhal          0      IN  1603380799       29     27.00
# 27        zvishavane          0      ZW  1603380803       39    -20.33
#
#     Longitude Max temp Wind speed Hotel Name Hotel Address Hotel Lat Hotel Lon
# 0       55.48       24        8.7
# 1       57.61    23.33       1.79
# 2       25.57       22        6.2
# 3      -50.01    23.84        4.3
# 4       27.91       23        7.7
# 5       18.42    21.11        9.3
# 6      118.57       23        4.6
# 7       26.89    23.02       8.67
# 8       19.23    22.78       3.13
# 9       42.45       24        4.6
# 10      11.87    25.08        6.7
# 11      75.38    22.83       2.09
# 12      55.77       24        8.7
# 13      15.95    22.84       1.55
# 14      67.82    23.95       0.52
# 15       8.92       23       1.01
# 16      21.55    22.09       4.38
# 17      40.92    25.49       4.08
# 18    -101.53     25.3       0.48
# 19     -17.03       27        7.2
# 20     -81.27       24        8.2
# 21      59.53    25.73        5.2
# 22      57.66    23.33       1.79
# 23     104.13       24        1.5
# 24      81.48       27        3.6
# 25      55.62       24        8.7
# 26      78.94    25.73       0.89
# 27      30.07    25.61       4.06

# %%
import json

# %%
# TESTING

# geocoordinates
target_coordinates = "-21.34, 55.48"
target_search = "Hotel"
target_radius = 5000
target_type = "hotel"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
response.json()
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIQEAAB1Gxs_sQGipISJPFYSxVD1L4qAZ5f0IMoJhvxoGpZ7JewnmaJWWeaV3YrV6ygdAer_MUUOsEVY6obTTsLi1NB9ESjW--tLwG6uUHPzm-N5SJXi7_Q6mEi7h_KKD-FA8-hvh47l2WJGpKpMRH--m5Oq3HOmxR-KUc5R8Lt13RxXYvbPAoX-Ph_jWgR7lm_cbqrk5JZ31e9rFdBfZUbcgE5LlsGrQdEwqYwDJSje4LGRFkeKDeqLpKbZqEQKZmpjAtJfK6YpH8IhPVpZZIsLl-iaMdVsK-KO7UCi4vLbIBRmf79aKjtuydgNVAd-rMJo0Vy7vcISlc-yZ3Mff6GpAeUii5EMEBuv8KVhxf4BUBc1mywVQrgC4K_OnHjgP7BLJ12oFk20xcZdxXNic1A9axTkSELe1hhRdop9-P0fFr6DRHKQaFBQzfGywfpSt0RxKGMguvsD0gD29',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3412423, 'lng': 55.4619647},
#     'viewport': {'northeast': {'lat': -21.33982537010728,
#       'lng': 55.46334642989272},
#      'southwest': {'lat': -21.34252502989272, 'lng': 55.46064677010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Le Battant Des Lames',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106074301522930126498">A Google User</a>'],
#      'photo_reference': 'CmRZAAAAM2NSk9Q09SS4PCeeAlqq5eccRQi1z7R8dU7KnLxoqjWApnycRMx9yVJ51wJIt9zlFRhPwfVC7jdNrNhA9KIUw-0DYcpUNbRxT8ymy0T_-5lKv2RKZxPoJVBXHY1fzavfEhCCXcUpkMalETy9aBJ8K9nuGhTq7FWdBWfWMAR4XWvTpF3cOC9KEQ',
#      'width': 5312}],
#    'place_id': 'ChIJ_-nuWcyggiERZ3QMMuG5hAo',
#    'plus_code': {'compound_code': 'MF56+GQ Saint Pierre, Réunion',
#     'global_code': '5HCQMF56+GQ'},
#    'rating': 4.2,
#    'reference': 'ChIJ_-nuWcyggiERZ3QMMuG5hAo',
#    'scope': 'GOOGLE',
#    'types': ['spa',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 376,
#    'vicinity': '117 Boulevard Hubert Delisle'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.34349, 'lng': 55.473758},
#     'viewport': {'northeast': {'lat': -21.34217857010728,
#       'lng': 55.47510777989272},
#      'southwest': {'lat': -21.34487822989272, 'lng': 55.47240812010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Villa Delisle, Hotel & Spa',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 465,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112920808453391739973">Villa Delisle, Hotel &amp; Spa</a>'],
#      'photo_reference': 'CmRaAAAA7M4lV1iLB5BPixh1BclMR8Vw0nche3TaZm5-93MB4w1PPca0c0YYzgw4ixGOzPJNgoLYej7Ji_vhvSuSQtzFxdpJInYLr0wmo0J0dPImiSrpNRG9oBbASSxZ1UNxIVRCEhCnCj5YPcHJime42FIAYt2iGhTxNVz24iIvbIbdLfK4RE8UYm2SAQ',
#      'width': 925}],
#    'place_id': 'ChIJRZMbZrSggiERxR7ktKmjRXU',
#    'plus_code': {'compound_code': 'MF4F+JG Saint Pierre, Réunion',
#     'global_code': '5HCQMF4F+JG'},
#    'rating': 4.2,
#    'reference': 'ChIJRZMbZrSggiERxR7ktKmjRXU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 213,
#    'vicinity': '42 Boulevard Hubert Delisle'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.341364, 'lng': 55.47433900000001},
#     'viewport': {'northeast': {'lat': -21.33996602010728,
#       'lng': 55.47570477989272},
#      'southwest': {'lat': -21.34266567989273, 'lng': 55.47300512010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel le Saint-Pierre',
#    'photos': [{'height': 3390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110379138366485505390">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAuYTX_zF5eOqsyBtfXVMZE_j7tdmcgypJbvAtqi2dFY6HO9Via-1TqAjyufa4YhNVhCxHF0cvSGzhNnE6Qfp6yIPkePG6MBxB7qflNEaq6uXJ_YR5uoVXD05JCHljd5MEEhDP1G1tF1fPdhU-c8tgl2lYGhTEwFhX6Y9UXkm-cmG_q3zlP2nDMw',
#      'width': 5084}],
#    'place_id': 'ChIJFcVtXrGggiERw_e2OeYAONQ',
#    'plus_code': {'compound_code': 'MF5F+FP Saint Pierre, Réunion',
#     'global_code': '5HCQMF5F+FP'},
#    'rating': 4.3,
#    'reference': 'ChIJFcVtXrGggiERw_e2OeYAONQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 220,
#    'vicinity': '51 Avenue des Indes, Saint-Pierre'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3427957, 'lng': 55.4696757},
#     'viewport': {'northeast': {'lat': -21.34143237010728,
#       'lng': 55.47098277989272},
#      'southwest': {'lat': -21.34413202989272, 'lng': 55.46828312010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Cap Sud',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117900508583663554430">Georges Soubou</a>'],
#      'photo_reference': 'CmRaAAAAxR8U72ymQiUMPa-sPJHNiG1RruklZMHiUy6LuBiyVewcgWCne4yAFH8PSOtXC4OAKYliTwj18tsx0nY3DxVtwO8ULps5jQw2ecTXDZccl1chOI_bwVMCUpjwDMdhRLgkEhBKKCYM6XRKxVfY1e0epgGdGhREEMttoGm7-iOBhpzhDrRumqnR0g',
#      'width': 4032}],
#    'place_id': 'ChIJo2WEhrWggiERNAX-1y6fT60',
#    'plus_code': {'compound_code': 'MF49+VV Saint Pierre, Réunion',
#     'global_code': '5HCQMF49+VV'},
#    'rating': 3.2,
#    'reference': 'ChIJo2WEhrWggiERNAX-1y6fT60',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 51,
#    'vicinity': '6 Rue Caumont'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.295929, 'lng': 55.51710929999999},
#     'viewport': {'northeast': {'lat': -21.29455537010728,
#       'lng': 55.51843697989272},
#      'southwest': {'lat': -21.29725502989272, 'lng': 55.51573732010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'BaraquaBaja Lodge',
#    'photos': [{'height': 2204,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103128711506155310628">A Google User</a>'],
#      'photo_reference': 'CmRZAAAAr5utzpg-KW3Rr2TiKgRMJ8eXK0xzgh947y9xG6jkyuR1uru0gC3Y-seMfdIG0cGsQzkdukKr6V0CnWurfLiULzyrGA-drIEPB_HYhCLcSrFGvCak8sjkjGhLOQHGVsGvEhCufhy9jjYuJGnmSOnpHjG9GhSodCLU5DhXSCDiTcPAcihpFP4_Qw',
#      'width': 3920}],
#    'place_id': 'ChIJ1dHKQuoKeCERTCC9WVkdvDM',
#    'plus_code': {'compound_code': 'PG38+JR Le Tampon, Réunion',
#     'global_code': '5HCQPG38+JR'},
#    'rating': 4.5,
#    'reference': 'ChIJ1dHKQuoKeCERTCC9WVkdvDM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '78 chemin de la pointe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.2961898, 'lng': 55.5070264},
#     'viewport': {'northeast': {'lat': -21.29478467010728,
#       'lng': 55.50842812989272},
#      'southwest': {'lat': -21.29748432989272, 'lng': 55.50572847010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Le Jardin de Ravintsara Gites LA REUNION',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2105,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114012604019642937069">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAbTWzzbi09dkMuj_OAQVx0Q5Iu4ijQxB1DIA-9iaAaDFkfwOH0XeFKZyxr9auwgBQpgjSfi5aiDkxtDRCbPsi5S4fPxIhZKSNyHaNulRG0bLMOQNJVhhR4K9WoD-fMoLaEhAXrSHGYXTDJo6WgC9ujJ5oGhRCUycLlaSoGxKBiwippticRrtsVg',
#      'width': 4032}],
#    'place_id': 'ChIJvYZKpkALeCERtLQpcnYRs7k',
#    'plus_code': {'compound_code': 'PG34+GR Le Tampon, Réunion',
#     'global_code': '5HCQPG34+GR'},
#    'rating': 4.9,
#    'reference': 'ChIJvYZKpkALeCERtLQpcnYRs7k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 13,
#    'vicinity': '103 E Ancienne Route Nationale 3'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3326735, 'lng': 55.5276327},
#     'viewport': {'northeast': {'lat': -21.33137182010728,
#       'lng': 55.52916322989272},
#      'southwest': {'lat': -21.33407147989272, 'lng': 55.52646357010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Le Soleil Couchant',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1908,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109230752821755994498">Henri Giraud</a>'],
#      'photo_reference': 'CmRaAAAASlKyY6iDkWwHTMszihMS2QqBBTlc_OD8r_3VQ7mrGzV6vIug00AiumhbN0cgCfLKHzrxHZG-B-GqvEb1k2VQVulD4J1b2jF-i_yMFbHUVe99RibBaByuSZKGjwiqBIdPEhAQqq0otrLq6L-Sgk0tlhltGhS-VhrR6Hr8ghPg3NLfQGKS0-xtyQ',
#      'width': 4032}],
#    'place_id': 'ChIJ3zlqRk8KeCERbyKIMQX9yJQ',
#    'plus_code': {'compound_code': 'MG8H+W3 La Plaine des Cafres, Réunion',
#     'global_code': '5HCQMG8H+W3'},
#    'rating': 4.2,
#    'reference': 'ChIJ3zlqRk8KeCERbyKIMQX9yJQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 44,
#    'vicinity': 'Réunion'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.2963006, 'lng': 55.499885},
#     'viewport': {'northeast': {'lat': -21.29496862010728,
#       'lng': 55.50126267989272},
#      'southwest': {'lat': -21.29766827989272, 'lng': 55.49856302010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'LODGE PALMAE',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1220,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111347447259532343642">Angelique Vimes</a>'],
#      'photo_reference': 'CmRaAAAAgq8zATrM-SEqXYAqeHhFl7TItMR2BZqC2njTAkdwuBuR0tQYadttyv2OKmhM0mp6KA29John0l_IquVC0yWgPu7Fe6HItjQ6dCCWJfXDdiUPQFw7qlmWOlNtuImkL0W0EhDvpBPQHzBwRL3NDwxLpK2CGhTYi8os1DpUgwWxDdT1-LYtKbfi4g',
#      'width': 2578}],
#    'place_id': 'ChIJO-FqLZoKeCERqIkrJpOjSQA',
#    'plus_code': {'compound_code': 'PF3X+FX Le Tampon, Réunion',
#     'global_code': '5HCQPF3X+FX'},
#    'rating': 4.8,
#    'reference': 'ChIJO-FqLZoKeCERqIkrJpOjSQA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': '59 Chemin Jules Ferry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3429676, 'lng': 55.4746612},
#     'viewport': {'northeast': {'lat': -21.34159982010728,
#       'lng': 55.47594277989272},
#      'southwest': {'lat': -21.34429947989272, 'lng': 55.47324312010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Le Nathania',
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110335761980361908284">Y Evans</a>'],
#      'photo_reference': 'CmRaAAAAP-9ODDgrfSI3aOwlhpyTT1HWUty78O1MXEebwC9oDgGxHahUX12NIhSeMKxNkSUB87i4v_P_r8pxHqWgXaSUaYHHOybfVIihNswU5Ee4ekYpTN4txjSeRtcUGvidiZ0OEhBEJhyA8P4FuLY_qpMwSdGjGhQCmp-fUVi4v6X5pKtU17WyDE8wSw',
#      'width': 3096}],
#    'place_id': 'ChIJm2UeC7SggiERTqX_h3pe4Mg',
#    'plus_code': {'compound_code': 'MF4F+RV Saint Pierre, Réunion',
#     'global_code': '5HCQMF4F+RV'},
#    'rating': 2.6,
#    'reference': 'ChIJm2UeC7SggiERTqX_h3pe4Mg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 52,
#    'vicinity': '12 Rue Francois de Mahy, S'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3441463, 'lng': 55.4717534},
#     'viewport': {'northeast': {'lat': -21.34279347010728,
#       'lng': 55.47311127989272},
#      'southwest': {'lat': -21.34549312989272, 'lng': 55.47041162010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Alizé Plage',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113861592584855707259">Andreas Egger</a>'],
#      'photo_reference': 'CmRaAAAA-OatioEAEpEyHXU4FdGi7z6lyArkagZdAfF-SfKcU_GwWJo0E1ZxBfYJChf4dQa180qByvr_NFkFehgI_S3hNLcJWgqPSY9ByLLPbiJHf5du18LfOOQiVUZbezKmj9pdEhCXrRhLtqSoK_GvnRRxGFEJGhTaRgBV9d890ya0J0T_8VIEhJRsoA',
#      'width': 6000}],
#    'place_id': 'ChIJ34pc_LiggiERFCGTt5k0vec',
#    'plus_code': {'compound_code': 'MF4C+8P Saint Pierre, Réunion',
#     'global_code': '5HCQMF4C+8P'},
#    'rating': 4,
#    'reference': 'ChIJ34pc_LiggiERFCGTt5k0vec',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 260,
#    'vicinity': '17 Bis Boulevard Hubert Delisle, Saint-Pierre'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3573861, 'lng': 55.5173832},
#     'viewport': {'northeast': {'lat': -21.35605677010728,
#       'lng': 55.51877597989272},
#      'southwest': {'lat': -21.35875642989272, 'lng': 55.51607632010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Le Victoria',
#    'photos': [{'height': 1538,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114604723040102332203">Emilie Sautron</a>'],
#      'photo_reference': 'CmRaAAAA8XdgrW6I89Wd2kwsZuDjn87WQVL8tjkIJnIHItSfLHNgenFZd_bee4F7N97dak-28EHrL2I0nP357ly9Fxafx_TgTFucD2-8i-xThpyasSVaptaC9J_iCG7ic7iyh2SoEhAFXvRggtWDKofZyxXQ3RFaGhTepyvTkQo6Vu1CPf941PXJantJOg',
#      'width': 2048}],
#    'place_id': 'ChIJ2zeZcYoJeCEROf4cyWyOdms',
#    'plus_code': {'compound_code': 'JGV8+2X Petite Île, Réunion',
#     'global_code': '5HCQJGV8+2X'},
#    'rating': 3.9,
#    'reference': 'ChIJ2zeZcYoJeCEROf4cyWyOdms',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 121,
#    'vicinity': '8 Allée des Lataniers'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3226237, 'lng': 55.4695063},
#     'viewport': {'northeast': {'lat': -21.32112562010728,
#       'lng': 55.47053317989272},
#      'southwest': {'lat': -21.32382527989272, 'lng': 55.46783352010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': "Couleurs K'fé",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1824,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105952783159323013513">Couleurs K&#39;Fé</a>'],
#      'photo_reference': 'CmRaAAAA5E6mN3gKpbjrW5gw6fd84boxnxuwjP2lBCY1eBeZbiFQsyJeM22cnTu-DE0D5iD46Uw2rasWQBHiNJ4Vuc1a_LGgIFJGDo0nXZnuWNQYQulZsIBthnfe1kZhrkzo7qBbEhBaaQxgGEfM34iazlGuw7uRGhR4rTSXfeEJeOk8vyMKN81-JHNNHw',
#      'width': 2432}],
#    'place_id': 'ChIJvzn4npSggiERfJhzQUsOOwg',
#    'plus_code': {'compound_code': 'MFG9+XR Saint Pierre, Réunion',
#     'global_code': '5HCQMFG9+XR'},
#    'rating': 4.9,
#    'reference': 'ChIJvzn4npSggiERfJhzQUsOOwg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 17,
#    'vicinity': '45 Allee Jacquot, Saint Pierre'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.341006, 'lng': 55.47229069999999},
#     'viewport': {'northeast': {'lat': -21.33967407010728,
#       'lng': 55.47363202989273},
#      'southwest': {'lat': -21.34237372989272, 'lng': 55.47093237010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Lindsey Hôtel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1365,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112102829978209841913">Lindsey Hotel</a>'],
#      'photo_reference': 'CmRaAAAAtUusC55FpWdj74aXE8r47Iiru7YV4GU4yIwzbBMkp30P_qwaAPg6A_5ATnyjRBCAc74hWpBBq5mLeRJuf5_O28u-oJNzauYXnc88Dpsg3CMU_hNdsTFQZ3RUHcB6mBVREhCOKdVALFfpzt0klwleWDjbGhQau-oDTKnSnic-s2AFTX0NLbcw1A',
#      'width': 2048}],
#    'place_id': 'ChIJI6Tjj7aggiERsLew4oUmhSE',
#    'plus_code': {'compound_code': 'MF5C+HW Saint Pierre, Réunion',
#     'global_code': '5HCQMF5C+HW'},
#    'rating': 4,
#    'reference': 'ChIJI6Tjj7aggiERsLew4oUmhSE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 90,
#    'vicinity': '21 Rue Francois Isautier'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.348634, 'lng': 55.48526},
#     'viewport': {'northeast': {'lat': -21.34726997010728,
#       'lng': 55.48656312989272},
#      'southwest': {'lat': -21.34996962989272, 'lng': 55.48386347010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Villa Morgane',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112481743546089619944">Hôtel Villa Morgane</a>'],
#      'photo_reference': 'CmRaAAAA-F7XnE_7O3eXwA8fPkgzbaIToZicHJinrFLq-Vp3qqQAfkIaBvX-qtd6xtR5jiNZ9jn7ICQ70QlDYNCC1sXa2ABZb6cbhE0rU_mnp9wNFoEfO05XlDciNpSpoQXQjirgEhBJ6jEHAJkLHSXyHJYu5tZzGhRvMe6wr2reHPhIvPp6ZKXn3OkQlA',
#      'width': 1914}],
#    'place_id': 'ChIJT_k4NlOngiER5OL2F6Vybzc',
#    'plus_code': {'compound_code': 'MF2P+G4 Saint Pierre, Réunion',
#     'global_code': '5HCQMF2P+G4'},
#    'rating': 4.2,
#    'reference': 'ChIJT_k4NlOngiER5OL2F6Vybzc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 102,
#    'vicinity': '334 Rue Amiral Lacaze'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.320265, 'lng': 55.47090069999999},
#     'viewport': {'northeast': {'lat': -21.31894052010728,
#       'lng': 55.47223042989272},
#      'southwest': {'lat': -21.32164017989272, 'lng': 55.46953077010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Maison Tonga Piscine Jacuzzi',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1282,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117382971465344857784">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAmcZl-xxycarlMHpg4E7EUKmThqPfHHEBgmEEIQ0Fv87tnoQd6SveSY5ZvXCsvTFZAANRxU2ANNiI5o8L1edDVFO4xDFz0kTWIOO4ecAo8FR6U_h2XNAUNeGfzZLf8nIqEhCLsC8bB66TuMF06j0ysasRGhTPErEH7vRw_fO4SkxbojdHeZnEnA',
#      'width': 1920}],
#    'place_id': 'ChIJ8aeCinmhgiERewkEtvw1VIM',
#    'plus_code': {'compound_code': 'MFHC+V9 Saint Pierre, Réunion',
#     'global_code': '5HCQMFHC+V9'},
#    'rating': 0,
#    'reference': 'ChIJ8aeCinmhgiERewkEtvw1VIM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '11b allée Marocath'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3426399, 'lng': 55.47539519999999},
#     'viewport': {'northeast': {'lat': -21.34123917010728,
#       'lng': 55.47676127989273},
#      'southwest': {'lat': -21.34393882989272, 'lng': 55.47406162010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Chez Papa Daya',
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108872032048360618162">Steeve israël Begue</a>'],
#      'photo_reference': 'CmRaAAAAENE1Pqa6KEc-ky0j39XVCkdJ21Yty6ndJfrYpkCd0DExRcYJdJsZsa-gGPqwm4UNuKezn8cqY9KGtVUSzhT9mb-eLZ9SiHVkyVdfC_lzTf2UFabqzdYJ1fsWPML6rZNaEhDO6oEk98Hhpujh46TYwxUoGhSSWdv74m-TM8_2GzBQjFpWVz8piA',
#      'width': 3264}],
#    'place_id': 'ChIJHW5b8LOggiERWkJy0IiItHI',
#    'plus_code': {'compound_code': 'MF4G+W5 Saint Pierre, Réunion',
#     'global_code': '5HCQMF4G+W5'},
#    'rating': 4.5,
#    'reference': 'ChIJHW5b8LOggiERWkJy0IiItHI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 71,
#    'vicinity': '27 Rue du Four à Chaux'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3335611, 'lng': 55.479637},
#     'viewport': {'northeast': {'lat': -21.33226027010728,
#       'lng': 55.48116072989272},
#      'southwest': {'lat': -21.33495992989272, 'lng': 55.47846107010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'La Villa Mae',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1756,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101842421748675656469">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAZu3iAlhK4MXS3g2f-iqtP0GBDuc1oXbSf5f_KjetifpAFHGR93xN-r4UnIRal4UYJlDnS2J9A7WA11p-yYfEGI8t0GmvBfXV72vDDMrbLP_a9qIu-4t1ERDbemmARJBmEhBpK9TxJ0LHnHqo5ilzcn8bGhQ7LLVc9k7uoirqeRCDPdI6RMBl-w',
#      'width': 3968}],
#    'place_id': 'ChIJu8bq5VGhgiERUWpvDMuESFA',
#    'plus_code': {'compound_code': 'MF8H+HV Saint Pierre, Réunion',
#     'global_code': '5HCQMF8H+HV'},
#    'rating': 4.8,
#    'reference': 'ChIJu8bq5VGhgiERUWpvDMuESFA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 16,
#    'vicinity': '3 Bis Rue Axel Dorseuil'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3472093, 'lng': 55.4810639},
#     'viewport': {'northeast': {'lat': -21.34585237010728,
#       'lng': 55.48239392989272},
#      'southwest': {'lat': -21.34855202989272, 'lng': 55.47969427010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Chambres d\'hôtes "Côté Lagon"',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109498033162651467778">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAsNMC5NVk1POeIZRPh1Q3H2PMesfO7NNZ1N2i_-aq1tV2aj9A0LxdEIRYsVQX5iP1eGt-x-nJBor_AAUsAtjl_tLhd8mtZ9AiOWXF1_4ddrypsSRcbGSk9nqFwEX17ZEZEhDkrs9GyExs8BGReHOGEsGXGhRD4OQkdjK3ih7GioEWf3pWJmM5jA',
#      'width': 4032}],
#    'place_id': 'ChIJS9Q2LK2ggiERtjGQlv0zcnM',
#    'plus_code': {'compound_code': 'MF3J+4C Saint Pierre, Réunion',
#     'global_code': '5HCQMF3J+4C'},
#    'rating': 4.9,
#    'reference': 'ChIJS9Q2LK2ggiERtjGQlv0zcnM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 55,
#    'vicinity': '79 Rue Amiral Lacaze'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3170336, 'lng': 55.5053153},
#     'viewport': {'northeast': {'lat': -21.31565787010727,
#       'lng': 55.50664587989272},
#      'southwest': {'lat': -21.31835752989272, 'lng': 55.50394622010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Gadiamb City',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101710610796100115943">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAQmN_KohaK3GR4NDshJCGBsiG3eEq0d8SfpcNpRgwdlxoB9Ar-XExQIatcDCjyzd1WlYAmgBF-BdL4tJdgt-C7ZBUaMVMXm4tgmFi8h_AQJwNqufr_S4cg6ZLJuMvMV0SEhA3IHZW12kSNBjhyNgb_yZOGhTRcdYagK8bETCQZnir3lGKskSovw',
#      'width': 600}],
#    'place_id': 'ChIJPYhVB1wLeCERNfqXCmUOqRQ',
#    'plus_code': {'compound_code': 'MGM4+54 Le Tampon, Réunion',
#     'global_code': '5HCQMGM4+54'},
#    'rating': 4.3,
#    'reference': 'ChIJPYhVB1wLeCERNfqXCmUOqRQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'lodging',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': '40 D Chemin Bassin Martin'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3006488, 'lng': 55.4873061},
#     'viewport': {'northeast': {'lat': -21.29928697010728,
#       'lng': 55.48864812989272},
#      'southwest': {'lat': -21.30198662989272, 'lng': 55.48594847010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'La Parenthèse - Villa et Appartement avec piscine en location saisonnière',
#    'photos': [{'height': 1067,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101036915049270348626">A Google User</a>'],
#      'photo_reference': 'CmRaAAAA-KG9v2qPOegVlpCKsKPy8SZjZL89k4BZ7o5GWuLogjzhohBjZvziwcMZJg5rh43Yu8O_dFyMJVEtyIVsxoXrnJYr7Xo_ZJ8VBwqrQQu9Y4CLwV8SA0LbfnEAhn3vBQ_5EhDnmgeVcz4uFPMMDYgbLZKPGhTQz_3Oypn8tyPFSI5DKIuJQ0tnHA',
#      'width': 1600}],
#    'place_id': 'ChIJwXKjDSKhgiERQHv-3b2YTbs',
#    'plus_code': {'compound_code': 'MFXP+PW Le Tampon, Réunion',
#     'global_code': '5HCQMFXP+PW'},
#    'rating': 5,
#    'reference': 'ChIJwXKjDSKhgiERQHv-3b2YTbs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '78 Chemin Periassamy'}],
#  'status': 'OK'}

# %%
first_hotel = response.json()

# %%
first_hotel["results"][0]["geometry"]["location"]["lat"]
# Out:
# -21.3412423

# %%
Hotel_list =[]

# %%
# Data extraction with API Key

for i, row in cities1_df.iterrows():
    target_coordinates = (f'{cities1_df.loc[i, "Latitude"]}, {cities1_df.loc[i, "Longitude"]}')
    target_search = "Hotel"
    target_radius = 5000
    target_type = "hotel"

    params = {
        "location": target_coordinates,
        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": g_key
    }
    
    response = requests.get(base_url, params=params)
    Hotel_list.append(response.json())

# %%
len(Hotel_list)
# Out:
# 28

# %%
for i, row in cities1_df.iterrows():
    try:
        cities1_df.loc[i, "Hotel Name"] = Hotel_list[i]["results"][0]["name"]
        cities1_df.loc[i, "Hotel Address"] = Hotel_list[i]["results"][0]["vicinity"]  
        cities1_df.loc[i, "Hotel Lat"] = Hotel_list[i]["results"][0]["geometry"]["location"]["lat"]
        cities1_df.loc[i, "Hotel Lon"] = Hotel_list[i]["results"][0]["geometry"]["location"]["lng"]
    except:
        cities1_df.loc[i, "Hotel Name"] = str('NaN')
        cities1_df.loc[i, "Hotel Address"] = str('NaN')  
        cities1_df.loc[i, "Hotel Lat"] = str('NaN')
        cities1_df.loc[i, "Hotel Lon"] = str('NaN')
        print(f'Data not found for {cities1_df.loc[i, "City"]}')
# Out:
# Data not found for faya
# Data not found for zaltan
# Data not found for abu kamal
# Data not found for wattegama

# %%
cities1_df
# Out:
#                 City Cloudiness Country        Date Humidity  Latitude  \
# 0       saint-pierre          0      RE  1603380285       73    -21.34
# 1     cap malheureux          0      MU  1603380577       71    -19.98
# 2     port elizabeth          0      ZA  1603380383       78    -33.92
# 3             castro          0      BR  1603380586       50    -24.79
# 4        east london          0      ZA  1603380320       73    -33.02
# 5          cape town          0      ZA  1603380590       72    -33.93
# 6       port hedland          0      AU  1603380593       83    -20.32
# 7        port alfred          0      ZA  1603380597       71    -33.59
# 8           hermanus          0      ZA  1603380603       65    -34.42
# 9               faya          0      SA  1603380617       13     18.39
# 10            zaltan          0      LY  1603380637       49     32.95
# 11             mansa          0      IN  1603380639       20     29.98
# 12    saint-philippe          0      RE  1603380646       73    -21.36
# 13               hun          0      LY  1603380665       30     29.13
# 14              bhag          0      PK  1603380674       14     29.04
# 15           ajaccio          0      FR  1603380677       53     42.00
# 16              jalu          0      LY  1603380683       35     29.03
# 17         abu kamal          0      SY  1603380685       24     34.45
# 18  san buenaventura          0      MX  1603380697       62     27.08
# 19        nouadhibou          0      MR  1603380709       61     20.93
# 20            talara          0      PE  1603380721       73     -4.58
# 21               sur          0      OM  1603380738       61     22.57
# 22       grand gaube          0      MU  1603380775       71    -20.01
# 23          yasothon          0      TH  1603380788       78     15.75
# 24         wattegama          0      LK  1603380792       94      6.80
# 25      saint-joseph          0      RE  1603380792       73    -21.37
# 26            karhal          0      IN  1603380799       29     27.00
# 27        zvishavane          0      ZW  1603380803       39    -20.33
#
#     Longitude Max temp Wind speed                       Hotel Name  \
# 0       55.48       24        8.7                     LODGE PALMAE
# 1       57.61    23.33       1.79     Paradise Cove Boutique Hotel
# 2       25.57       22        6.2                 Island Way Villa
# 3      -50.01    23.84        4.3             Urano Business Hotel
# 4       27.91       23        7.7         Premier Hotels & Resorts
# 5       18.42    21.11        9.3               One&Only Cape Town
# 6      118.57       23        4.6              The Esplanade Hotel
# 7       26.89    23.02       8.67           Royal St Andrews Hotel
# 8       19.23    22.78       3.13              Harbour House Hotel
# 9       42.45       24        4.6
# 10      11.87    25.08        6.7
# 11      75.38    22.83       2.09              Mehak Resorts HOTEL
# 12      55.77       24        8.7             Les Embruns Du Baril
# 13      15.95    22.84       1.55                    Alrwasi Hotel
# 14      67.82    23.95       0.52                     Bukhari hotl
# 15       8.92       23       1.01                       Chalet zen
# 16      21.55    22.09       4.38                       Jalu Hotel
# 17      40.92    25.49       4.08
# 18    -101.53     25.3       0.48               Hotel Villa Jardín
# 19     -17.03       27        7.2       Free Zone Hotel Nouadhibou
# 20     -81.27       24        8.2      Casa Andina Standard Talara
# 21      59.53    25.73        5.2                  Sur Plaza Hotel
# 22      57.66    23.33       1.79  LUX Grand Gaube Resort & Villas
# 23     104.13       24        1.5                   BM Grand Hotel
# 24      81.48       27        3.6
# 25      55.62       24        8.7              Bubble Dome Village
# 26      78.94    25.73       0.89               Aiza Resort Karhal
# 27      30.07    25.61       4.06                  Pote Hill Hotel
#
#                                         Hotel Address Hotel Lat Hotel Lon
# 0                               59 Chemin Jules Ferry  -21.2963   55.4999
# 1                             Royal Road Anse La Raie  -19.9879   57.6327
# 2        2 Hartley Rd, Millard Grange, Port Elizabeth  -33.9459    25.593
# 3     R. José Marques, 26 - Vila Frei Mathias, Castro  -24.8034  -50.0118
# 4   2nd Floor Elicc Building, Marine Park Complex ...  -33.0187   27.9187
# 5   One&Only Cape Town, Dock Rd, Victoria & Alfred...  -33.9086   18.4163
# 6                         2 Anderson St, Port Hedland  -20.3139   118.576
# 7                       19 St Andrews Rd, Port Alfred  -33.6032   26.8868
# 8                             22 Harbour Rd, Hermanus  -34.4212   19.2432
# 9
# 10
# 11  Near Nehru Memorial Government College Sirsa, ...   30.0214   75.3972
# 12                                            Réunion  -21.3692   55.7279
# 13                                      houn-aljoufra   29.1171   15.9159
# 14                                               Bhag   29.0421   67.8245
# 15      Plaine de Peri 8, Chemin de Petra Rossa, Peri   41.9951   8.86322
# 16                                               Jalu   29.0327   21.5458
# 17
# 18  Carretera Federal 30, San Buenaventura Centro,...   27.0436  -101.555
# 19                                       Unnamed Road    20.939  -17.0345
# 20                      Av. Bolognesi 143-145, Talara  -4.57518  -81.2755
# 21                                                Sur   22.5664   59.4959
# 22                      MU, Coastal Road, Grand Gaube  -20.0023   57.6598
# 23  105/4 Rattana Khet Alley, Nai Mueang, Mueang Y...    15.797   104.145
# 24
# 25             18 chemin, Ligne des Quatre Cent Vingt  -21.3666   55.6373
# 26                               hafeez nagar, Karhal    27.004   78.9371
# 27                                         Zvishavane  -20.3086   30.0459

# %%
output_data_file = "../output_data/hotel_DF.csv"
cities1_df.to_csv(output_data_file, index = False)

# %%
file_import = os.path.join("..","output_data","hotel_DF.csv")

# %%
with open(file_import, "r", encoding="utf-8-sig") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",")
    csv_header = next(csv_reader)
    hotel_df = pd.DataFrame(csv_reader, columns = csv_header)

# %%
hotel_df
# Out:
#                 City Cloudiness Country        Date Humidity Latitude  \
# 0       saint-pierre          0      RE  1603380285       73   -21.34
# 1     cap malheureux          0      MU  1603380577       71   -19.98
# 2     port elizabeth          0      ZA  1603380383       78   -33.92
# 3             castro          0      BR  1603380586       50   -24.79
# 4        east london          0      ZA  1603380320       73   -33.02
# 5          cape town          0      ZA  1603380590       72   -33.93
# 6       port hedland          0      AU  1603380593       83   -20.32
# 7        port alfred          0      ZA  1603380597       71   -33.59
# 8           hermanus          0      ZA  1603380603       65   -34.42
# 9               faya          0      SA  1603380617       13    18.39
# 10            zaltan          0      LY  1603380637       49    32.95
# 11             mansa          0      IN  1603380639       20    29.98
# 12    saint-philippe          0      RE  1603380646       73   -21.36
# 13               hun          0      LY  1603380665       30    29.13
# 14              bhag          0      PK  1603380674       14    29.04
# 15           ajaccio          0      FR  1603380677       53     42.0
# 16              jalu          0      LY  1603380683       35    29.03
# 17         abu kamal          0      SY  1603380685       24    34.45
# 18  san buenaventura          0      MX  1603380697       62    27.08
# 19        nouadhibou          0      MR  1603380709       61    20.93
# 20            talara          0      PE  1603380721       73    -4.58
# 21               sur          0      OM  1603380738       61    22.57
# 22       grand gaube          0      MU  1603380775       71   -20.01
# 23          yasothon          0      TH  1603380788       78    15.75
# 24         wattegama          0      LK  1603380792       94      6.8
# 25      saint-joseph          0      RE  1603380792       73   -21.37
# 26            karhal          0      IN  1603380799       29     27.0
# 27        zvishavane          0      ZW  1603380803       39   -20.33
#
#    Longitude Max temp Wind speed                       Hotel Name  \
# 0      55.48       24        8.7                     LODGE PALMAE
# 1      57.61    23.33       1.79     Paradise Cove Boutique Hotel
# 2      25.57       22        6.2                 Island Way Villa
# 3     -50.01    23.84        4.3             Urano Business Hotel
# 4      27.91       23        7.7         Premier Hotels & Resorts
# 5      18.42    21.11        9.3               One&Only Cape Town
# 6     118.57       23        4.6              The Esplanade Hotel
# 7      26.89    23.02       8.67           Royal St Andrews Hotel
# 8      19.23    22.78       3.13              Harbour House Hotel
# 9      42.45       24        4.6                              NaN
# 10     11.87    25.08        6.7                              NaN
# 11     75.38    22.83       2.09              Mehak Resorts HOTEL
# 12     55.77       24        8.7             Les Embruns Du Baril
# 13     15.95    22.84       1.55                    Alrwasi Hotel
# 14     67.82    23.95       0.52                     Bukhari hotl
# 15      8.92       23       1.01                       Chalet zen
# 16     21.55    22.09       4.38                       Jalu Hotel
# 17     40.92    25.49       4.08                              NaN
# 18   -101.53     25.3       0.48               Hotel Villa Jardín
# 19    -17.03       27        7.2       Free Zone Hotel Nouadhibou
# 20    -81.27       24        8.2      Casa Andina Standard Talara
# 21     59.53    25.73        5.2                  Sur Plaza Hotel
# 22     57.66    23.33       1.79  LUX Grand Gaube Resort & Villas
# 23    104.13       24        1.5                   BM Grand Hotel
# 24     81.48       27        3.6                              NaN
# 25     55.62       24        8.7              Bubble Dome Village
# 26     78.94    25.73       0.89               Aiza Resort Karhal
# 27     30.07    25.61       4.06                  Pote Hill Hotel
#
#                                         Hotel Address          Hotel Lat  \
# 0                               59 Chemin Jules Ferry        -21.2963006
# 1                             Royal Road Anse La Raie        -19.9878899
# 2        2 Hartley Rd, Millard Grange, Port Elizabeth          -33.94592
# 3     R. José Marques, 26 - Vila Frei Mathias, Castro        -24.8033628
# 4   2nd Floor Elicc Building, Marine Park Complex ...        -33.0186916
# 5   One&Only Cape Town, Dock Rd, Victoria & Alfred...        -33.9086313
# 6                         2 Anderson St, Port Hedland        -20.3139254
# 7                       19 St Andrews Rd, Port Alfred        -33.6032154
# 8                             22 Harbour Rd, Hermanus        -34.4211674
# 9                                                 NaN                NaN
# 10                                                NaN                NaN
# 11  Near Nehru Memorial Government College Sirsa, ...         30.0214044
# 12                                            Réunion        -21.3692006
# 13                                      houn-aljoufra         29.1171477
# 14                                               Bhag         29.0421302
# 15      Plaine de Peri 8, Chemin de Petra Rossa, Peri         41.9950521
# 16                                               Jalu  29.03272369999999
# 17                                                NaN                NaN
# 18  Carretera Federal 30, San Buenaventura Centro,...         27.0435501
# 19                                       Unnamed Road         20.9389501
# 20                      Av. Bolognesi 143-145, Talara          -4.575182
# 21                                                Sur         22.5664354
# 22                      MU, Coastal Road, Grand Gaube         -20.002344
# 23  105/4 Rattana Khet Alley, Nai Mueang, Mueang Y...         15.7970128
# 24                                                NaN                NaN
# 25             18 chemin, Ligne des Quatre Cent Vingt           -21.3666
# 26                               hafeez nagar, Karhal         27.0040335
# 27                                         Zvishavane        -20.3085941
#
#              Hotel Lon
# 0            55.499885
# 1    57.63265249999999
# 2               25.593
# 3   -50.01184989999999
# 4           27.9186969
# 5           18.4162905
# 6          118.5760814
# 7           26.8868014
# 8           19.2431805
# 9                  NaN
# 10                 NaN
# 11          75.3972409
# 12          55.7279486
# 13          15.9158511
# 14   67.82445109999999
# 15           8.8632219
# 16          21.5458054
# 17                 NaN
# 18          -101.55493
# 19         -17.0345462
# 20  -81.27546099999999
# 21          59.4958585
# 22           57.659766
# 23         104.1446165
# 24                 NaN
# 25           55.637328
# 26          78.9371302
# 27          30.0458761

# %%
hotel_df.dtypes
# Out:
# City             object
# Cloudiness       object
# Country          object
# Date             object
# Humidity         object
# Latitude         object
# Longitude        object
# Max temp         object
# Wind speed       object
# Hotel Name       object
# Hotel Address    object
# Hotel Lat        object
# Hotel Lon        object
# dtype: object

# %%
hotel_df.drop(hotel_df.loc[hotel_df['Hotel Name']=='NaN'].index, inplace=True)

# %%
hotel_df
# Out:
#                 City  Cloudiness Country        Date  Humidity  Latitude  \
# 0       saint-pierre           0      RE  1603380285        73    -21.34
# 1     cap malheureux           0      MU  1603380577        71    -19.98
# 2     port elizabeth           0      ZA  1603380383        78    -33.92
# 3             castro           0      BR  1603380586        50    -24.79
# 4        east london           0      ZA  1603380320        73    -33.02
# 5          cape town           0      ZA  1603380590        72    -33.93
# 6       port hedland           0      AU  1603380593        83    -20.32
# 7        port alfred           0      ZA  1603380597        71    -33.59
# 8           hermanus           0      ZA  1603380603        65    -34.42
# 11             mansa           0      IN  1603380639        20     29.98
# 12    saint-philippe           0      RE  1603380646        73    -21.36
# 13               hun           0      LY  1603380665        30     29.13
# 14              bhag           0      PK  1603380674        14     29.04
# 15           ajaccio           0      FR  1603380677        53     42.00
# 16              jalu           0      LY  1603380683        35     29.03
# 18  san buenaventura           0      MX  1603380697        62     27.08
# 19        nouadhibou           0      MR  1603380709        61     20.93
# 20            talara           0      PE  1603380721        73     -4.58
# 21               sur           0      OM  1603380738        61     22.57
# 22       grand gaube           0      MU  1603380775        71    -20.01
# 23          yasothon           0      TH  1603380788        78     15.75
# 25      saint-joseph           0      RE  1603380792        73    -21.37
# 26            karhal           0      IN  1603380799        29     27.00
# 27        zvishavane           0      ZW  1603380803        39    -20.33
#
#     Longitude  Max temp  Wind speed                       Hotel Name  \
# 0       55.48     24.00        8.70                     LODGE PALMAE
# 1       57.61     23.33        1.79     Paradise Cove Boutique Hotel
# 2       25.57     22.00        6.20                 Island Way Villa
# 3      -50.01     23.84        4.30             Urano Business Hotel
# 4       27.91     23.00        7.70         Premier Hotels & Resorts
# 5       18.42     21.11        9.30               One&Only Cape Town
# 6      118.57     23.00        4.60              The Esplanade Hotel
# 7       26.89     23.02        8.67           Royal St Andrews Hotel
# 8       19.23     22.78        3.13              Harbour House Hotel
# 11      75.38     22.83        2.09              Mehak Resorts HOTEL
# 12      55.77     24.00        8.70             Les Embruns Du Baril
# 13      15.95     22.84        1.55                    Alrwasi Hotel
# 14      67.82     23.95        0.52                     Bukhari hotl
# 15       8.92     23.00        1.01                       Chalet zen
# 16      21.55     22.09        4.38                       Jalu Hotel
# 18    -101.53     25.30        0.48               Hotel Villa Jardín
# 19     -17.03     27.00        7.20       Free Zone Hotel Nouadhibou
# 20     -81.27     24.00        8.20      Casa Andina Standard Talara
# 21      59.53     25.73        5.20                  Sur Plaza Hotel
# 22      57.66     23.33        1.79  LUX Grand Gaube Resort & Villas
# 23     104.13     24.00        1.50                   BM Grand Hotel
# 25      55.62     24.00        8.70              Bubble Dome Village
# 26      78.94     25.73        0.89               Aiza Resort Karhal
# 27      30.07     25.61        4.06                  Pote Hill Hotel
#
#                                         Hotel Address          Hotel Lat  \
# 0                               59 Chemin Jules Ferry        -21.2963006
# 1                             Royal Road Anse La Raie        -19.9878899
# 2        2 Hartley Rd, Millard Grange, Port Elizabeth          -33.94592
# 3     R. José Marques, 26 - Vila Frei Mathias, Castro        -24.8033628
# 4   2nd Floor Elicc Building, Marine Park Complex ...        -33.0186916
# 5   One&Only Cape Town, Dock Rd, Victoria & Alfred...        -33.9086313
# 6                         2 Anderson St, Port Hedland        -20.3139254
# 7                       19 St Andrews Rd, Port Alfred        -33.6032154
# 8                             22 Harbour Rd, Hermanus        -34.4211674
# 11  Near Nehru Memorial Government College Sirsa, ...         30.0214044
# 12                                            Réunion        -21.3692006
# 13                                      houn-aljoufra         29.1171477
# 14                                               Bhag         29.0421302
# 15      Plaine de Peri 8, Chemin de Petra Rossa, Peri         41.9950521
# 16                                               Jalu  29.03272369999999
# 18  Carretera Federal 30, San Buenaventura Centro,...         27.0435501
# 19                                       Unnamed Road         20.9389501
# 20                      Av. Bolognesi 143-145, Talara          -4.575182
# 21                                                Sur         22.5664354
# 22                      MU, Coastal Road, Grand Gaube         -20.002344
# 23  105/4 Rattana Khet Alley, Nai Mueang, Mueang Y...         15.7970128
# 25             18 chemin, Ligne des Quatre Cent Vingt           -21.3666
# 26                               hafeez nagar, Karhal         27.0040335
# 27                                         Zvishavane        -20.3085941
#
#              Hotel Lon
# 0            55.499885
# 1    57.63265249999999
# 2               25.593
# 3   -50.01184989999999
# 4           27.9186969
# 5           18.4162905
# 6          118.5760814
# 7           26.8868014
# 8           19.2431805
# 11          75.3972409
# 12          55.7279486
# 13          15.9158511
# 14   67.82445109999999
# 15           8.8632219
# 16          21.5458054
# 18          -101.55493
# 19         -17.0345462
# 20  -81.27546099999999
# 21          59.4958585
# 22           57.659766
# 23         104.1446165
# 25           55.637328
# 26          78.9371302
# 27          30.0458761

# %%
hotel_df = hotel_df.apply(pd.to_numeric, errors='ignore')
hotel_df.dtypes
# Out:
# City              object
# Cloudiness         int64
# Country           object
# Date               int64
# Humidity           int64
# Latitude         float64
# Longitude        float64
# Max temp         float64
# Wind speed       float64
# Hotel Name        object
# Hotel Address     object
# Hotel Lat        float64
# Hotel Lon        float64
# dtype: object

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Hotel Lat", "Hotel Lon"]]

# %%
hotel_info
# Out:
# ['\n<dl>\n<dt>Name</dt><dd>LODGE PALMAE</dd>\n<dt>City</dt><dd>saint-pierre</dd>\n<dt>Country</dt><dd>RE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Paradise Cove Boutique Hotel</dd>\n<dt>City</dt><dd>cap malheureux</dd>\n<dt>Country</dt><dd>MU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Island Way Villa</dd>\n<dt>City</dt><dd>port elizabeth</dd>\n<dt>Country</dt><dd>ZA</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Urano Business Hotel</dd>\n<dt>City</dt><dd>castro</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Premier Hotels & Resorts</dd>\n<dt>City</dt><dd>east london</dd>\n<dt>Country</dt><dd>ZA</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>One&Only Cape Town</dd>\n<dt>City</dt><dd>cape town</dd>\n<dt>Country</dt><dd>ZA</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>The Esplanade Hotel</dd>\n<dt>City</dt><dd>port hedland</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Royal St Andrews Hotel</dd>\n<dt>City</dt><dd>port alfred</dd>\n<dt>Country</dt><dd>ZA</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Harbour House Hotel</dd>\n<dt>City</dt><dd>hermanus</dd>\n<dt>Country</dt><dd>ZA</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Mehak Resorts HOTEL</dd>\n<dt>City</dt><dd>mansa</dd>\n<dt>Country</dt><dd>IN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Les Embruns Du Baril</dd>\n<dt>City</dt><dd>saint-philippe</dd>\n<dt>Country</dt><dd>RE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Alrwasi Hotel</dd>\n<dt>City</dt><dd>hun</dd>\n<dt>Country</dt><dd>LY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Bukhari hotl</dd>\n<dt>City</dt><dd>bhag</dd>\n<dt>Country</dt><dd>PK</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Chalet zen</dd>\n<dt>City</dt><dd>ajaccio</dd>\n<dt>Country</dt><dd>FR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Jalu Hotel</dd>\n<dt>City</dt><dd>jalu</dd>\n<dt>Country</dt><dd>LY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Hotel Villa Jardín</dd>\n<dt>City</dt><dd>san buenaventura</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Free Zone Hotel Nouadhibou</dd>\n<dt>City</dt><dd>nouadhibou</dd>\n<dt>Country</dt><dd>MR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Casa Andina Standard Talara</dd>\n<dt>City</dt><dd>talara</dd>\n<dt>Country</dt><dd>PE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Sur Plaza Hotel</dd>\n<dt>City</dt><dd>sur</dd>\n<dt>Country</dt><dd>OM</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>LUX Grand Gaube Resort & Villas</dd>\n<dt>City</dt><dd>grand gaube</dd>\n<dt>Country</dt><dd>MU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>BM Grand Hotel</dd>\n<dt>City</dt><dd>yasothon</dd>\n<dt>Country</dt><dd>TH</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Bubble Dome Village</dd>\n<dt>City</dt><dd>saint-joseph</dd>\n<dt>Country</dt><dd>RE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Aiza Resort Karhal</dd>\n<dt>City</dt><dd>karhal</dd>\n<dt>Country</dt><dd>IN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Pote Hill Hotel</dd>\n<dt>City</dt><dd>zvishavane</dd>\n<dt>Country</dt><dd>ZW</dd>\n</dl>\n']

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(marker_layer)
fig

# Display Map
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='500px', margin='0 auto 0 auto', padding='1px', wi…
